# %%
import os
import os.path as osp
import numpy as np
import pickle
import matplotlib.pyplot as plt
import numpy.linalg as LA

experiment_name = "drone_xz"
logdir = "/home/desong/Shaohang/plot_states"

# %%
with open(osp.join(logdir, "run_stats.pkl"), "rb") as f:
    data = pickle.load(f)   
train_stats = data["train_stats"]

start = -1
num_traj = 200

for j in range(start, start-num_traj, -1):
    traj = train_stats[j]
    xs = []
    zs = []
    for i in range(len(traj)-1):
        step_stats = traj[i]
        state = step_stats["state"]
        xs.append(state[0])
        zs.append(state[1])
        # print(state)
    
    
    last_state = step_stats["state"]
    fig, axs = plt.subplots(1, figsize=(8, 8))
    axs.plot(xs, zs, '-')
    axs.plot(xs[0], zs[0], 'r*', markersize=12) # start point
    axs.plot(xs[-1], zs[-1], 'bo', markersize=12) # end point
    print("=============== trajectory {} ===============".format(j))
    print("end velocity: vx=", last_state[2], " vz=", last_state[3], "mag=", np.sqrt(last_state[2]**2 + last_state[3]**2))
    print("distance:", LA.norm(last_state[:2]-np.array([0, 0.5])))
    print("epi_steps: ", len(traj))
    rectangle_lower = plt.Rectangle((-1, 0.1), 0.5, 0.9)
    rectangle_higher = plt.Rectangle((0, 1.3), 1, 0.5)
    ground = plt.Rectangle((-4, 0), 5, 0.2)
    axs.set_ylim(0, 1.8)
    axs.set_xlim(-3, 1)
    plt.gca().add_patch(rectangle_lower)
    plt.gca().add_patch(rectangle_higher)
    plt.gca().add_patch(ground)
    plt.show()
# Out:
# =============== trajectory -10 ===============
# end velocity: vx= -0.031377810799952666  vz= -0.2168728588133646 mag= 0.21913101994121964
# distance: 0.32513637829778896
# epi_steps:  100
# =============== trajectory -11 ===============
# end velocity: vx= 0.0  vz= 0.0 mag= 0.0
# distance: 1.1395495885032414
# epi_steps:  2
# =============== trajectory -12 ===============
# end velocity: vx= -0.03749988903344533  vz= -0.2243206695630493 mag= 0.22743351659492816
# distance: 0.3367189243969608
# epi_steps:  97
# =============== trajectory -13 ===============
# end velocity: vx= -0.13270587356249908  vz= -0.18682784128215768 mag= 0.22916258672858683
# distance: 0.3410020645792595
# epi_steps:  11
# =============== trajectory -14 ===============
# end velocity: vx= -0.05407199974496488  vz= -0.22085862373455406 mag= 0.22738142587806245
# distance: 0.31850013553210477
# epi_steps:  102
# =============== trajectory -15 ===============
# end velocity: vx= 0.17376438693218235  vz= 0.1800595245253111 mag= 0.25023088246297315
# distance: 1.1118868817856613
# epi_steps:  26
# =============== trajectory -16 ===============
# end velocity: vx= 0.024411455668280915  vz= -0.20395698606646087 mag= 0.2054126854241455
# distance: 0.32815851359571263
# epi_steps:  86
# =============== trajectory -17 ===============
# end velocity: vx= 0.08974436452945965  vz= 0.17577728786164978 mag= 0.197361865345851
# distance: 1.1536620731715928
# epi_steps:  4
# =============== trajectory -18 ===============
# end velocity: vx= 0.058385882535810806  vz= -0.20869113663238123 mag= 0.21670464182476737
# distance: 0.32779927055619373
# epi_steps:  80
# =============== trajectory -19 ===============
# end velocity: vx= -0.03896349369198941  vz= -0.2249699955583298 mag= 0.2283191904816602
# distance: 0.3224423057494432
# epi_steps:  32
# =============== trajectory -20 ===============
# end velocity: vx= -0.04273344923978064  vz= -0.22725220814568386 mag= 0.23123519150643598
# distance: 0.33330028823316055
# epi_steps:  105
# =============== trajectory -21 ===============
# end velocity: vx= 0.04727325056052682  vz= -0.1860664707923288 mag= 0.19197784187679287
# distance: 0.3407557434831138
# epi_steps:  95
# =============== trajectory -22 ===============
# end velocity: vx= 0.17530728500029055  vz= 0.17591480789546105 mag= 0.2483518951227674
# distance: 1.1485112532433082
# epi_steps:  15
# =============== trajectory -23 ===============
# end velocity: vx= 0.17526261181496003  vz= 0.17781410208899529 mag= 0.2496694574871284
# distance: 1.124657252904813
# epi_steps:  24
# =============== trajectory -24 ===============
# end velocity: vx= 0.16124375824948814  vz= -0.22693523531073817 mag= 0.2783866925698128
# distance: 0.34341139306399143
# epi_steps:  105
# =============== trajectory -25 ===============
# end velocity: vx= -0.07962197732936387  vz= -0.2188432604647112 mag= 0.2328777188239853
# distance: 0.3225555555889117
# epi_steps:  48
# =============== trajectory -26 ===============
# end velocity: vx= 0.1759507353479714  vz= 0.1750123560160899 mag= 0.24816926890288907
# distance: 1.1598365705825893
# epi_steps:  27
# =============== trajectory -27 ===============
# end velocity: vx= -0.08487630961883555  vz= -0.2190939168369211 mag= 0.23495985259072694
# distance: 0.3297192702929733
# epi_steps:  112
# =============== trajectory -28 ===============
# end velocity: vx= -0.11280733782404949  vz= -0.2099992840753246 mag= 0.23838035736842517
# distance: 0.3255750897187762
# epi_steps:  20
# =============== trajectory -29 ===============
# end velocity: vx= -0.03869355788828973  vz= -0.1809095208269018 mag= 0.18500120580113427
# distance: 0.34440444879054893
# epi_steps:  89
# =============== trajectory -30 ===============
# end velocity: vx= -0.05865798199363108  vz= -0.18593265019090416 mag= 0.194965918197459
# distance: 0.3225152524668698
# epi_steps:  102
# =============== trajectory -31 ===============
# end velocity: vx= 0.13312229218312377  vz= -0.24270535727105072 mag= 0.2768166091912791
# distance: 0.33714867079563005
# epi_steps:  31
# =============== trajectory -32 ===============
# end velocity: vx= -0.09457811863601846  vz= -0.18918129258194114 mag= 0.2115055129014438
# distance: 0.3268743739455252
# epi_steps:  54
# =============== trajectory -33 ===============
# end velocity: vx= 0.14059788244659574  vz= -0.21527965459902196 mag= 0.2571246667139132
# distance: 0.3349884289739641
# epi_steps:  67
# =============== trajectory -34 ===============
# end velocity: vx= -0.08583988855765494  vz= -0.2067548659346818 mag= 0.22386616773255144
# distance: 0.331005178912159
# epi_steps:  14
# =============== trajectory -35 ===============
# end velocity: vx= -0.013477277348322731  vz= -0.18125234376901553 mag= 0.18175271422040717
# distance: 0.33297818725970313
# epi_steps:  57
# =============== trajectory -36 ===============
# end velocity: vx= 0.06685296953625539  vz= -0.23044615396572588 mag= 0.23994738884474348
# distance: 0.3337556124093588
# epi_steps:  31
# =============== trajectory -37 ===============
# end velocity: vx= 0.05793664135043427  vz= -0.19749862730251513 mag= 0.20582118986476253
# distance: 0.3499346196231953
# epi_steps:  104
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-6-f3a47d1a2b27> in <module>
#      21     fig, axs = plt.subplots(1, figsize=(8, 8))
#      22     axs.plot(xs, zs, '-')
# ---> 23     axs.plot(xs[0], zs[0], 'r*', markersize=12) # start point
#      24     axs.plot(xs[-1], zs[-1], 'bo', markersize=12) # end point
#      25     print("=============== trajectory {} ===============".format(j))
#
# IndexError: list index out of range
